# %%
import pandas as pd
import numpy as np

# %%
tracks = pd.read_csv('sample_data/ant_tracking_res.csv').rename(columns={'frame': 't'}).drop(columns=['index'])
tracks.head()
# Out:
#    trackid  t           x           y
# 0        1  1  580.501357  115.399131
# 1        1  2  579.075777  114.465839
# 2        1  3  578.348231  113.751474
# 3        1  4  578.200176  113.350906
# 4        1  5  578.507421  113.289936

# %% [markdown]
# # Simple

# %%
import plotly.offline
import trackviz.plotly.static

plotly.offline.init_notebook_mode(connected=True)  # must be called to use offline.iplot

fig = trackviz.plotly.static.trajectory_3d(tracks)
plotly.offline.iplot(fig)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ...
